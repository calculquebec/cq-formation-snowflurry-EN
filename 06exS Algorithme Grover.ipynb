# %% [markdown]
# ## The circuit
# ![GroverAlgo.png](attachment:5c03c6f6-55f8-4d70-b6d7-d81fef775d8b.png)
# __[Source](https://www.quantum-inspire.com/kbase/grover-algorithm/)__

# %%
using Snowflurry

# %%
using SnowflurryPlots
# Out:
# WebIO._IJuliaInit()

# %%
greg = QuantumCircuit(qubit_count=3)
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# q[1]:
#
# q[2]:
#
# q[3]:

# %%
push!(greg, hadamard(1), hadamard(2), hadamard(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# q[1]:──H────────────
#
# q[2]:───────H───────
#
# q[3]:────────────H──

# %%
push!(greg, sigma_x(1), hadamard(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# q[1]:──H──────────────X───────
#
# q[2]:───────H─────────────────
#
# q[3]:────────────H─────────H──

# %%
push!(greg,toffoli(1,2,3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# q[1]:──H──────────────X─────────*──
#                                 |
# q[2]:───────H───────────────────*──
#                                 |
# q[3]:────────────H─────────H────X──

# %%
push!(greg, sigma_x(1), hadamard(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# q[1]:──H──────────────X─────────*────X───────
#                                 |
# q[2]:───────H───────────────────*────────────
#                                 |
# q[3]:────────────H─────────H────X─────────H──

# %%
push!(greg, hadamard(1), hadamard(2), hadamard(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# q[1]:──H──────────────X─────────*────X─────────H────────────
#                                 |
# q[2]:───────H───────────────────*───────────────────H───────
#                                 |
# q[3]:────────────H─────────H────X─────────H──────────────H──

# %%
push!(greg, sigma_x(1), sigma_x(2), sigma_x(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# Part 1 of 2
# q[1]:──H──────────────X─────────*────X─────────H──────────────X───────
#                                 |
# q[2]:───────H───────────────────*───────────────────H──────────────X──
#                                 |
# q[3]:────────────H─────────H────X─────────H──────────────H────────────
#
#
# Part 2 of 2
# q[1]:─────
#
# q[2]:─────
#
# q[3]:──X──

# %%
push!(greg, hadamard(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# Part 1 of 2
# q[1]:──H──────────────X─────────*────X─────────H──────────────X───────
#                                 |
# q[2]:───────H───────────────────*───────────────────H──────────────X──
#                                 |
# q[3]:────────────H─────────H────X─────────H──────────────H────────────
#
#
# Part 2 of 2
# q[1]:──────────
#
# q[2]:──────────
#
# q[3]:──X────H──

# %%
push!(greg,toffoli(1,2,3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# Part 1 of 2
# q[1]:──H──────────────X─────────*────X─────────H──────────────X───────
#                                 |
# q[2]:───────H───────────────────*───────────────────H──────────────X──
#                                 |
# q[3]:────────────H─────────H────X─────────H──────────────H────────────
#
#
# Part 2 of 2
# q[1]:────────────*──
#                  |
# q[2]:────────────*──
#                  |
# q[3]:──X────H────X──

# %%
push!(greg, hadamard(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# Part 1 of 2
# q[1]:──H──────────────X─────────*────X─────────H──────────────X───────
#                                 |
# q[2]:───────H───────────────────*───────────────────H──────────────X──
#                                 |
# q[3]:────────────H─────────H────X─────────H──────────────H────────────
#
#
# Part 2 of 2
# q[1]:────────────*───────
#                  |
# q[2]:────────────*───────
#                  |
# q[3]:──X────H────X────H──

# %%
push!(greg, sigma_x(1), sigma_x(2), sigma_x(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# Part 1 of 2
# q[1]:──H──────────────X─────────*────X─────────H──────────────X───────
#                                 |
# q[2]:───────H───────────────────*───────────────────H──────────────X──
#                                 |
# q[3]:────────────H─────────H────X─────────H──────────────H────────────
#
#
# Part 2 of 2
# q[1]:────────────*─────────X────────────
#                  |
# q[2]:────────────*──────────────X───────
#                  |
# q[3]:──X────H────X────H──────────────X──

# %%
push!(greg, hadamard(1), hadamard(2), hadamard(3))
# Out:
# Quantum Circuit Object:
#    qubit_count: 3
# Part 1 of 2
# q[1]:──H──────────────X─────────*────X─────────H──────────────X───────
#                                 |
# q[2]:───────H───────────────────*───────────────────H──────────────X──
#                                 |
# q[3]:────────────H─────────H────X─────────H──────────────H────────────
#
#
# Part 2 of 2
# q[1]:────────────*─────────X──────────────H────────────
#                  |
# q[2]:────────────*──────────────X──────────────H───────
#                  |
# q[3]:──X────H────X────H──────────────X──────────────H──

# %%
simulate(greg)
# Out:
# 8-element Ket{ComplexF64}:
# -0.1767766952966367 + 0.0im
# -0.1767766952966367 + 0.0im
# -0.17677669529663664 + 0.0im
# -0.8838834764831834 + 0.0im
# -0.17677669529663667 + 0.0im
# -0.17677669529663667 + 0.0im
# -0.17677669529663667 + 0.0im
# -0.17677669529663667 + 0.0im

# %%
plot_histogram(greg,1000)
